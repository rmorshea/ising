# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation
# %matplotlib inline

# %%
import antipackage
from github.rmorshea.IsingModel import ising
ising.clear_output() #ignore errors

# %% [markdown]
# ---
# ##GIF Making

# %%
lat = ising.Lattice(100,100,0.5,1.5,nghbrs=4,size=2)
lat
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks8d037bb0-55d7-476f-8fd1-bd67f2c8b82d td {border: 0px solid white;}</style><table id="blocks8d037bb0-55d7-476f-8fd1-bd67f2c8b82d" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 0)" style="width: 2px; height: 2px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (255, 255, 255)" style="width: 2px; height: 2px;background-color: rgb(255, 255, 255);"></td><td title="Index: [0, 2]&#10;Color: (0, 0, 0)" style="width: 2px; height: 2px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (255, 255, 255)" style="width: 2px; height: 2px;background-color: rgb(255, 255, 255);"></td><td title="Index: [0, 4]&#10;Color: (255, 255, 255)" style="width: 2px; height: 2px;background-color: rgb(255, 255, 255);"></td><td title="Index: [0, 5]&#10;Color: (255, 255, 255)" style="width: 2px; height: 2px;background-color: rgb(255, 255, 255);"></td><td title="Index: [0, 6]&#10;Color: (255, 255, 255)" style="width: 2px; height: 2px;background-color: rgb(255, 255, 255);"></td><td title="Index: [0, 7]&#10;Color: (0, 0, 0)" style="width: 2px; height: 2px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 8]&#10;Color: (255, 255, 255)" style="width: 2px; height: 2px;background-color: rgb(255, 255, 255);"></td><td title="Index: [0, 9]&#10;Color: (255, 255, 255)" style="width: 2px; height: 2px;background-color: rgb(255, 255, 255);"></td><td title="Index: [0, 10]&#10;Color: (255, 255, 255)" style="width: 2px; height: 2px;background-color: rgb(255, 255, 255);"></td><td title="Index: [0, 11]&#10;Color: (0, 0, 0)" style="width: 2px; height: 2px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 12]&#10;Color: (255, 255, 255)" style="width: 2px; height: 2px;background-color: rgb(255, 255, 255);"></td><td title="Index: [0, 13]&#10;Color: (255, 255, 255)" style="width: 2px; height: 2px;background-color: rgb(255, 255, 255);"></td><td title="Index: [0, 14]&#10;Color: (0, 0, 0)" style="width: 2px; height: 2px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 15]&#10;Color: (0, 0, 0)" style="width: 2px; height: 2px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 16]&#10;Color: (255, 255, 255)" style="width: 2px; height: 2px;background-color: rgb(255, 255, 255);"></td><td title="Index: [0, 17]&#10;Color: (0, 0, 0)" style="width: 2px; height: 2px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 18]&#10;Color: (0, 0, 0)" style="width: 2px; height: 2px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 19]&#10;Color: (255, 255, 255)" style="width: 2px; height: 2px;background-color: rgb(255, 255, 255);"></td><td title="Index: [0, 20]&#10;Color: (0, 0, 0)" style="width: 2px; height: 2px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 21]&#10;Color: (255, 255, 255)" style="width: 2px; height: 2px;background-color: rgb(255, 255, 255);"></td><td title="Index: [0, 22]&#10;Color: (255, 255, 255)" style="width: 2px; height: 2px;background-color: rgb(255, 255, 255);"></td><td title="Index: [0, 23]&#10;Color: (255, 255, 255)" style="width: 2px; height: 2px;background-color: rgb(255, 255, 255);"></td><td title="Index: [0, 24]&#10;Color: (0, 0, 0)" style="width: 2px; height: 2px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 25]&#10;Color: (255, 255, 255)" style="width: 2px; height: 2px;background-color: rgb(255, 255, 255);"></td><td title="Index: [0, 26]&#10;Color: (255, 255, 255)" style="width: 2px; height: 2px;background-color: rgb(255, 255, 255);"></td><td title="Index: [0, 27]&#10;Color: (0, 0, 0)" style="width: 2px; height: 2px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 28]&#10;Color: (255, 255, 255)" style="width: 2px; height: 2px;background-color: rgb(255, 255, 255);"></td><td title="Index: [0, 29]&#10;Color: (0, 0, 0)" style="width: 2px; height: 2px;background-color: rgb(0, 0, 0);"></td><td  ...

# %%
lat.animate(2000, 160)

# %%
lat.make_pngs()
lat.make_gif('Teq1.5',0.075)

# %% [markdown]
# ---
# ##Perform Analysis

# %%
T = list(np.linspace(1,5,1200))
lat = ising.Lattice(10,10,0,T,nghbrs=4,size=5)

# %%
lat.animate(750,display=False)

# %%
data = lat.analyze()

# %%
plt.figure(figsize=(10,5))
plt.scatter(T,data[0],marker='.')
plt.xlabel(r'$T$',fontsize=15)
plt.ylabel(r'$M$',fontsize=15)
plt.xlim(T[0],T[-1])
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(T,data[1])
plt.xlabel(r'$T$',fontsize=15)
plt.ylabel(r'$U_{avg}$',fontsize=15)
plt.xlim(T[0],T[-1])
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(T,data[2])
plt.xlabel(r'$T$')
plt.ylabel(r'$C_v$')
plt.xlim(T[0],T[-1])
plt.show()
